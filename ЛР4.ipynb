# %% [markdown]
# <a href="https://colab.research.google.com/github/Darianath/CSVD/blob/main/%D0%9B%D0%A04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна 4, Назарової Дар'ї

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fac8b92d-1335-419a-a92f-182af68a5f27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fac8b92d-1335-419a-a92f-182af68a5f27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Museum_Visitors.csv')
df
# Out:
#                      Month  America Tropical Interpretive Center  Avila Adobe  \
# 0   01/01/2014 12:00:00 AM                                  6602        24778
# 1   02/01/2014 12:00:00 AM                                  5029        18976
# 2   03/01/2014 12:00:00 AM                                  8129        25231
# 3   04/01/2014 12:00:00 AM                                  2824        26989
# 4   05/01/2014 12:00:00 AM                                 10694        36883
# ..                     ...                                   ...          ...
# 80  09/01/2020 12:00:00 AM                                     0            0
# 81  10/01/2020 12:00:00 AM                                     0            0
# 82  11/01/2020 12:00:00 AM                                     0            0
# 83  12/01/2020 12:00:00 AM                                     0            0
# 84  01/01/2021 12:00:00 AM                                     0            0
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Month                                  85 non-null     object
#  1   America Tropical Interpretive Center   85 non-null     int64
#  2   Avila Adobe                            85 non-null     int64
#  3   Chinese American Museum                85 non-null     int64
#  4   Gateway to Nature Center               32 non-null     float64
#  5   Firehouse Museum                       85 non-null     int64
#  6   Hellman Quon                           26 non-null     float64
#  7   IAMLA                                  54 non-null     float64
#  8   Pico House                             83 non-null     float64
#  9   Visitor Center/ El Tranquilo Gallery   45 non-null     float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Month                                     0
# America Tropical Interpretive Center      0
# Avila Adobe                               0
# Chinese American Museum                   0
# Gateway to Nature Center                 53
# Firehouse Museum                          0
# Hellman Quon                             59
# IAMLA                                    31
# Pico House                                2
# Visitor Center/ El Tranquilo Gallery     40
# Museum of Social Justice                 48
# Biscailuz Gallery/ PK Outdoor Exhibit    46
# dtype: int64

# %%
df = df.fillna(df.mean(numeric_only=True), axis=0)

# %%
df.isnull().sum()
# Out:
# Month                                    0
# America Tropical Interpretive Center     0
# Avila Adobe                              0
# Chinese American Museum                  0
# Gateway to Nature Center                 0
# Firehouse Museum                         0
# Hellman Quon                             0
# IAMLA                                    0
# Pico House                               0
# Visitor Center/ El Tranquilo Gallery     0
# Museum of Social Justice                 0
# Biscailuz Gallery/ PK Outdoor Exhibit    0
# dtype: int64

# %%
df.head()
# Out:
#                     Month  America Tropical Interpretive Center  Avila Adobe  \
# 0  01/01/2014 12:00:00 AM                                  6602        24778
# 1  02/01/2014 12:00:00 AM                                  5029        18976
# 2  03/01/2014 12:00:00 AM                                  8129        25231
# 3  04/01/2014 12:00:00 AM                                  2824        26989
# 4  05/01/2014 12:00:00 AM                                 10694        36883
#
#    Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# 0                     1581                  1247.375              4486
# 1                     1785                  1247.375              4172
# 2                     3229                  1247.375              7082
# 3                     2129                  1247.375              6756
# 4                     3676                  1247.375             10858
#
#    Hellman Quon       IAMLA  Pico House   \
# ...

# %%
df.describe()
# Out:
#        America Tropical Interpretive Center   Avila Adobe  \
# count                             85.000000     85.000000
# mean                            5637.694118  19904.952941
# std                             3277.453044   9495.340548
# min                                0.000000      0.000000
# 25%                             3891.000000  17056.000000
# 50%                             5705.000000  20815.000000
# 75%                             6955.000000  25234.000000
# max                            13490.000000  41242.000000
#
#        Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# count                85.000000                 85.000000         85.000000
# mean               2359.117647               1247.375000       5286.776471
# std                1360.427221                736.364942       6591.535926
# min                   0.000000                  0.000000          0.000000
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('/', '_').str.replace('__', '_').str.strip()
df.columns
# Out:
# Index(['month', 'america_tropical_interpretive_center', 'avila_adobe',
#        'chinese_american_museum', 'gateway_to_nature_center',
#        'firehouse_museum', 'hellman_quon', 'iamla', 'pico_house_',
#        'visitor_center_el_tranquilo_gallery', 'museum_of_social_justice',
#        'biscailuz_gallery_pk_outdoor_exhibit'],
#       dtype='object')

# %%
df.tail()
# Out:
#         month  america_tropical_interpretive_center  avila_adobe  \
# 80 2020-09-01                                     0            0
# 81 2020-10-01                                     0            0
# 82 2020-11-01                                     0            0
# 83 2020-12-01                                     0            0
# 84 2021-01-01                                     0            0
#
#     chinese_american_museum  gateway_to_nature_center  firehouse_museum  \
# 80                        0                       0.0                 0
# 81                        0                       0.0                 0
# 82                        0                       0.0                 0
# 83                        0                       0.0                 0
# 84                        0                       0.0                 0
#
#     hellman_quon  iamla  pico_house_  visitor_center_el_tranquilo_gallery  \
# ...

# %%
df['month'] = pd.to_datetime(df['month'], format='%m/%d/%Y %I:%M:%S %p')

df_2018 = df[df['month'].dt.year == 2018]

min_visitors = df_2018.iloc[:, 1:].min()
max_visitors = df_2018.iloc[:, 1:].max()
result = pd.DataFrame({'min': min_visitors, 'max': max_visitors})

result
# Out:
#                                                min           max
# america_tropical_interpretive_center   3180.000000   5837.000000
# avila_adobe                           14718.000000  25173.000000
# chinese_american_museum                2078.000000   4960.000000
# gateway_to_nature_center               1247.375000   1247.375000
# firehouse_museum                       3306.000000   8013.000000
# hellman_quon                            353.461538    353.461538
# iamla                                   965.000000   1601.000000
# pico_house_                             185.000000   2140.000000
# visitor_center_el_tranquilo_gallery    2634.800000   2634.800000
# museum_of_social_justice               2332.000000   3686.000000
# biscailuz_gallery_pk_outdoor_exhibit    349.000000   1790.000000

# %%
average_visitors = df.iloc[:, 1:].mean()
average_visitors
# Out:
# america_tropical_interpretive_center     5637.694118
# avila_adobe                             19904.952941
# chinese_american_museum                  2359.117647
# gateway_to_nature_center                 1247.375000
# firehouse_museum                         5286.776471
# hellman_quon                              353.461538
# iamla                                     882.611111
# pico_house_                              1329.710843
# visitor_center_el_tranquilo_gallery      2634.800000
# museum_of_social_justice                 2125.972973
# biscailuz_gallery_pk_outdoor_exhibit     1088.615385
# dtype: float64

# %%
df_2015 = df.loc[df['month'].dt.year == 2015].copy()

df_2015['total_visitors'] = df_2015.iloc[:, 1:].sum(axis=1)

min_row = df_2015.loc[df_2015['total_visitors'].idxmin()]
max_row = df_2015.loc[df_2015['total_visitors'].idxmax()]

min_month = min_row['month'].strftime('%B')
max_month = max_row['month'].strftime('%B')

print(f'Найнижча відвідуваність у {min_month}')
print(f'Найвища відвідуваність у {max_month}')
# Out:
# Найнижча відвідуваність у February
# Найвища відвідуваність у May

# %%
df_2015.head()
# Out:
#         month  america_tropical_interpretive_center  avila_adobe  \
# 12 2015-01-01                                  6250        20438
# 13 2015-02-01                                  5907        15578
# 14 2015-03-01                                  9884        21297
# 15 2015-04-01                                  7254        26670
# 16 2015-05-01                                 13207        34383
#
#     chinese_american_museum  gateway_to_nature_center  firehouse_museum  \
# 12                     1823                  1247.375              3858
# 13                     1558                  1247.375              3742
# 14                     2336                  1247.375              5390
# 15                     3057                  1247.375              7000
# 16                     4009                  1247.375             12528
#
#     hellman_quon       iamla  pico_house_  \
# 12          75.0  882.611111        200.0
# 13         160.0  882.611111       1075.0
# ...

# %%
df_2018 = df[df['month'].dt.year == 2018].copy()

df_2018['month_num'] = df_2018['month'].dt.month

summer = df_2018[df_2018['month_num'].isin([6, 7, 8])]['avila_adobe'].sum()

winter = df_2018[df_2018['month_num'].isin([1, 2, 12])]['avila_adobe'].sum()

print(f" Літом відвідали: {summer} людей")
print(f" Зимою відвідали: {winter} людей")
# Out:
#  Літом відвідали: 66122 людей
#  Зимою відвідали: 48705 людей

# %%
df_2018.head()
# Out:
#         month  america_tropical_interpretive_center  avila_adobe  \
# 48 2018-03-01                                  4909        19001
# 49 2018-02-01                                  5705        14718
# 50 2018-04-01                                  4650        18966
# 51 2018-01-01                                  5837        16265
# 52 2018-05-01                                  5626        25173
#
#     chinese_american_museum  gateway_to_nature_center  firehouse_museum  \
# 48                     4529                  1247.375              5225
# 49                     2710                  1247.375              3306
# 50                     2750                  1247.375              4535
# 51                     2477                  1247.375              3910
# 52                     4960                  1247.375              8013
#
#     hellman_quon   iamla  pico_house_  visitor_center_el_tranquilo_gallery  \
# ...

# %%
df.corr()
# Out:
#                                          month  \
# month                                 1.000000
# america_tropical_interpretive_center -0.781557
# avila_adobe                          -0.738084
# chinese_american_museum              -0.315742
# gateway_to_nature_center             -0.331943
# firehouse_museum                     -0.371774
# hellman_quon                          0.020910
# iamla                                -0.216164
# pico_house_                          -0.475915
# visitor_center_el_tranquilo_gallery  -0.013956
# museum_of_social_justice             -0.150472
# biscailuz_gallery_pk_outdoor_exhibit  0.074758
#
#                                       america_tropical_interpretive_center  \
# month                                                            -0.781557
# america_tropical_interpretive_center                              1.000000
# avila_adobe                                                       0.854877
# ...

# %%
mtx = df.corr(numeric_only=True).abs()

fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(
    mtx,
    cmap='crest',
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    mask=np.triu(np.ones_like(mtx, dtype=bool)),
    square=True,
    cbar=False,
    ax=ax
)

plt.title("Матриця попарної кореляції ознак", fontsize=14)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12, 6))

ax = sns.lineplot(
    data=df,
    x='month',
    y='iamla',
    marker='o',
    linewidth=2.5,
    color='#2e7d32'
)

plt.title('Динаміка відвідуваності iamla', fontsize=16, pad=20)
plt.xlabel('Місяць', fontsize=12)
plt.ylabel('Кількість відвідувачів', fontsize=12)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
df['year'] = df['month'].dt.year

plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")

sns.boxplot(
    data=df,
    x='year',
    y='hellman_quon',
    palette='Set2',
    width=0.6,
    showfliers=False
)

sns.stripplot(
    data=df,
    x='year',
    y='hellman_quon',
    color=".3",
    size=4,
    alpha=0.5
)

plt.title('Розподіл відвідуваності Hellman Quon за роками', fontsize=14, pad=15)
plt.xlabel('Рік', fontsize=12)
plt.ylabel('Кількість відвідувачів', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_288/1300863804.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
plt.figure(figsize=(10, 6))
plt.title("Розподіл відвідуваності Firehouse Museum")

sns.histplot(data=df['firehouse_museum'], bins=20, kde=True, color='orange')

plt.xlabel("Кількість відвідувачів")
plt.ylabel("Частота (кількість місяців)")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

avg_visitors = df.drop(columns=['month', 'year']).mean(numeric_only=True).sort_values(ascending=False)

sns.barplot(x=avg_visitors.values, y=avg_visitors.index, palette='viridis')

plt.title('Середня кількість відвідувачів по музеях', fontsize=14)
plt.xlabel('Середнє значення', fontsize=12)
plt.ylabel('Музей', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_288/1931660688.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_visitors.values, y=avg_visitors.index, palette='viridis')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e8feb4c-1e13-4ca3-af6c-cc169e213812" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e8feb4c-1e13-4ca3-af6c-cc169e213812">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df = df.fillna(df.mean(numeric_only=True), axis=0)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('/', '_').str.replace('__', '_').str.strip()
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Матриця кореляції числових ознак", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="island", y="flipper_length_mm", hue="species", split=False, inner="quart")
plt.title("Flipper Length by Island and Species")
plt.show()

# %%
df = sns.load_dataset('penguins').dropna()
sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="bill_length_mm", y="bill_depth_mm", hue="species", style="species", s=100, alpha=0.8)

plt.title("Взаємозв'язок довжини та глибини дзьоба", fontsize=14)
plt.xlabel("Довжина дзьоба (мм)")
plt.ylabel("Глибина дзьоба (мм)")
plt.legend(title="Вид пінгвіна", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="species", y="body_mass_g", hue="sex", palette="Set2", width=0.6)

plt.title("Розподіл маси тіла за видами та статтю", fontsize=14)
plt.xlabel("Вид пінгвіна")
plt.ylabel("Маса тіла (г)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
g = sns.jointplot(data=df, x="flipper_length_mm", y="body_mass_g", kind="reg",
                  color="#2ecc71", scatter_kws={'alpha':0.5})

g.fig.suptitle("Регресійна залежність маси від довжини плавців", y=1.02, fontsize=14)
g.set_axis_labels("Довжина плавця (мм)", "Маса тіла (г)")
plt.show()
